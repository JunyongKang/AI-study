# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

data=pd.read_csv('input/train.csv')

# %%
#data.isnull().sum()

f,ax = plt.subplots(1,2,figsize=(14,11))
data['Survived'].value_counts().plot.pie(explode=[0,0.05],autopct="%1.0f%%",ax=ax[0],shadow=False)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data, ax=ax[1])
ax[1].set_title('Survived')
plt.show()
#필기
#figsize: 전체 이미지의 가로세로 조절
#data['value'].value_counts().plot.pie(explode=[간격,간격],autopct="소수점: %1.nf%%")

# %%
data.groupby(['Pclass','Sex','Survived'])['Survived'].count()
# Out:
# Pclass  Sex     Survived
# 1       female  0             3
#                 1            91
#         male    0            77
#                 1            45
# 2       female  0             6
#                 1            70
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: Survived, dtype: int64

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_b882a554_454f_11e9_a0fc_e82a44af0174row0_col0 {
#             background-color:  #ffff66;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row0_col1 {
#             background-color:  #cee666;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row0_col2 {
#             background-color:  #f4fa66;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row1_col0 {
#             background-color:  #f6fa66;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row1_col1 {
#             background-color:  #ffff66;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row1_col2 {
#             background-color:  #ffff66;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row2_col0 {
#             background-color:  #60b066;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row2_col1 {
#             background-color:  #dfef66;
#         }    #T_b882a554_454f_11e9_a0fc_e82a44af0174row2_col2 {
#             background-color:  #90c866;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['black','white','red'],ax=ax[0])
ax[0].set_title('Passengers by pclass')
ax[0].set_ylabel('count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
sns.factorplot('Sex','Survived',hue='Pclass',data=data)
plt.show()

# %%
print(data['Age'].max())
f,ax = plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age",hue="Survived",data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs survived')
ax[0].set_yticks(range(0,110,5))
sns.violinplot("Sex","Age",hue="Survived",data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,5))
plt.show()
# Out:
# 80.0

# %%
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col0 {
#             background-color:  #ffff66;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col1 {
#             background-color:  #ffff66;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col2 {
#             background-color:  #008066;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col3 {
#             background-color:  #ffff66;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col4 {
#             background-color:  #ffff66;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col5 {
#             background-color:  #ffff66;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col6 {
#             background-color:  #008066;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col7 {
#             background-color:  #ffff66;
#         }    #T_41d98ac8_4572_11e9_beca_e82a44af0174row0_col8 {
#             background-color:  #ffff66;
# ...

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived = 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
_,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.close(2)
plt.show()

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# *SNS.heatmap : 숫자 데이터간 비례비율을 보여준다

# %%
sns.heatmap(data.corr(),annot =True,cmap='RdYlGn',linewidths=0.2)
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()
